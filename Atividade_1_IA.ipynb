# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniellineto/Atividades_Softex_IA-IOT/blob/main/Atividade_1_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercícios de Árvores de Decisão**
#
#
#
# Aluno: Daniel Lima Neto

# %%
# Importanto bibliotecas
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics

import pandas as pd

# %% [markdown]
# Primeira árvore

# %%
url = "https://raw.githubusercontent.com/Daniellineto/Atividades_Softex_IA-IOT/refs/heads/main/IA/ATV_1/iris.data"
dataset = pd.read_csv(url, header=None)
columns = len(dataset.columns)

y = dataset.iloc[:, -1]
X = dataset.iloc[:, :-1]
print(dataset)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Divisão 80% treino e 20% teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None, stratify=y)

# %%
# Cria classificador e treina o modelo
model = tree.DecisionTreeClassifier(criterion="entropy")
model = model.fit(X_train, y_train)

# %%
# Utiliza do modelo para fazer a previsão dos dados X_test
result = model.predict(X_test)

# Estimativa da precisão dos acertos
acc = metrics.accuracy_score(result, y_test)
show = round(acc * 100)
print("{}%".format(show))

# Comparação das respostas
print(list(result))
print(list(y_test))
# Out:
# 93%
# ['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa']
# ['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa']

# %%
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[2] <= 2.45\nentropy = 1.585\nsamples = 120\nvalue = [40, 40, 40]'),
#  Text(0.3, 0.75, 'entropy = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.35, 0.8333333333333333, 'True  '),
#  Text(0.5, 0.75, 'x[2] <= 4.85\nentropy = 1.0\nsamples = 80\nvalue = [0, 40, 40]'),
#  Text(0.45, 0.8333333333333333, '  False'),
#  Text(0.2, 0.5833333333333334, 'x[3] <= 1.65\nentropy = 0.286\nsamples = 40\nvalue = [0, 38, 2]'),
#  Text(0.1, 0.4166666666666667, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.3, 0.4166666666666667, 'x[1] <= 3.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.2, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5833333333333334, 'x[3] <= 1.75\nentropy = 0.286\nsamples = 40\nvalue = [0, 2, 38]'),
#  Text(0.7, 0.4166666666666667, 'x[2] <= 5.05\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.6, 0.25, 'x[0] <= 6.35\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.5, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.9, 0.4166666666666667, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]')]

# %% [markdown]
# Segunda árvore

# %%
# Carregando os dados
from scipy.io import arff

# Lendo o arquivo .arff
data_bean, meta = arff.loadarff("Dry_Bean_Dataset.arff")

# Convertendo para DataFrame do pandas
df = pd.DataFrame(data_bean)

# Caso os dados venham como bytes (em colunas categóricas), decodifica:
df['Class'] = df['Class'].str.decode('utf-8')

# %%
y = dataset.iloc[:, -1]
X = dataset.iloc[:, :-1]

# %%
# Divisão 80% treino e 20% teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)

# %%
# Cria classificador e treina o modelo
model = tree.DecisionTreeClassifier(criterion="entropy")
model = model.fit(X_train, y_train)

# %%
# Utiliza do modelo para fazer a previsão dos dados X_test
result = model.predict(X_test)

# Estimativa da precisão dos acertos
acc = metrics.accuracy_score(result, y_test)
show = round(acc * 100)
print("{}%".format(show))

# Comparação das respostas
print(list(result))
print(list(y_test))
# Out:
# 97%
# ['Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica']
# ['Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica']

# %%
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.75\nentropy = 1.585\nsamples = 120\nvalue = [40, 40, 40]'),
#  Text(0.4230769230769231, 0.75, 'entropy = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\nentropy = 1.0\nsamples = 80\nvalue = [0, 40, 40]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\nentropy = 0.446\nsamples = 43\nvalue = [0, 39, 4]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\nentropy = 0.176\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.07692307692307693, 0.25, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.23076923076923078, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\nentropy = 0.971\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.38461538461538464, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\nentropy = 0.179\nsamples = 37\nvalue = [0, 1, 36]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 6.05\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.6923076923076923, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'entropy = 0.0\nsamples = 35\nvalue = [0, 0, 35]')]
